# %%
import pandas as pd

# %%
## read in data 
banned_books_data = pd.read_csv("../datasets/PEN America's Index of School Book Bans (July 1, 2021 - June 30, 2022) - Sorted by Author & Title.csv", skiprows=2)

# %%
banned_books_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2532 entries, 0 to 2531
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Author                     2532 non-null   object
#  1   Title                      2532 non-null   object
#  2   Type of Ban                2532 non-null   object
#  3   Secondary Author(s)        166 non-null    object
#  4   Illustrator(s)             546 non-null    object
#  5   Translator(s)              27 non-null     object
#  6   State                      2532 non-null   object
#  7   District                   2532 non-null   object
#  8   Date of Challenge/Removal  2532 non-null   object
#  9   Origin of Challenge        2532 non-null   object
# dtypes: object(10)
# memory usage: 197.9+ KB

# %%
# column names need to be snake_case format: lowercase, and spaces replaced with _
banned_books_data.columns = banned_books_data.columns.str.lower()
banned_books_data.columns = banned_books_data.columns.str.replace(' ', '_')

# %%
# convert date_of_challenge/removal from object to DateTime type
banned_books_data['date_of_challenge/removal'] = pd.to_datetime(banned_books_data['date_of_challenge/removal'], format='%B %Y')
banned_books_data['date_of_challenge/removal'].dtype
# Out:
# dtype('<M8[ns]')

# %%
## check for duplicates
banned_books_data.duplicated().sum()
# Out:
# 0

# %%
# state bans count 
banned_books_data['state'].value_counts()
# Out:
# Texas             801
# Florida           566
# Pennsylvania      458
# Tennessee         349
# Oklahoma           43
# Michigan           41
# Kansas             30
# Wisconsin          29
# Missouri           27
# Idaho              26
# Georgia            23
# Mississippi        22
# Virginia           19
# Indiana            18
# North Carolina     16
# New York           13
# Utah               12
# Iowa                8
# Illinois            5
# South Dakota        5
# Washington          5
# Ohio                4
# New Jersey          3
# Minnesota           1
# Maryland            1
# Vermont             1
# Alaska              1
# Rhode Island        1
# Maine               1
# South Carolina      1
# Arkansas            1
# Oregon              1
# Name: state, dtype: int64

# %% [markdown]
# Texas, Florida, Pennsylvania and Tennessee have the largest number of banned books.

# %%
# books banned in NY 
ny_banned_books = banned_books_data[banned_books_data['state']=='New York']
ny_banned_books
# Out:
#                   author                                        title  \
# 3     Acevedo, Elizabeth                                   The Poet X
# 628     Evison, Jonathan                                     Lawn Boy
# 825          Green, John                           Looking for Alaska
# 1085  Johnson, George M.                         All Boys Aren't Blue
# 1236        Kobabe, Maia                       Gender Queer: A Memoir
# 1237        Kobabe, Maia                       Gender Queer: A Memoir
# 1238        Kobabe, Maia                       Gender Queer: A Memoir
# 1286       Kuklin, Susan  Beyond Magenta: Transgender Teens Speak Out
# 1643      Morrison, Toni                               The Bluest Eye
# 1815  Pérez, Ashley Hope                              Out of Darkness
# 1990        Rosen, L. C.             Jack of Hearts (and other parts)
# 2266          Stone, Nic                                  Dear Martin
# 2349       Thomas, Angie                              The Hate U Give
#
#                              type_of_ban secondary_author(s) illustrator(s)  \
# 3     Banned in Libraries and Classrooms                 NaN            NaN
# 628         Banned Pending Investigation                 NaN            NaN
# 825         Banned Pending Investigation                 NaN            NaN
# 1085        Banned Pending Investigation                 NaN            NaN
# 1236        Banned Pending Investigation                 NaN            NaN
# 1237  Banned in Libraries and Classrooms                 NaN            NaN
# 1238        Banned Pending Investigation                 NaN            NaN
# 1286        Banned Pending Investigation                 NaN            NaN
# 1643        Banned Pending Investigation                 NaN            NaN
# 1815        Banned Pending Investigation                 NaN            NaN
# 1990        Banned Pending Investigation                 NaN            NaN
# 2266  Banned in Libraries and Classrooms                 NaN            NaN
# 2349        Banned Pending Investigation                 NaN            NaN
#
#      translator(s)     state                            district  \
# 3              NaN  New York    Marlboro Central School District
# 628            NaN  New York    Yorktown Central School District
# 825            NaN  New York    Yorktown Central School District
# 1085           NaN  New York    Yorktown Central School District
# 1236           NaN  New York  Connetquot Central School District
# 1237           NaN  New York  Wappingers Central School District
# 1238           NaN  New York    Yorktown Central School District
# 1286           NaN  New York    Yorktown Central School District
# 1643           NaN  New York    Yorktown Central School District
# 1815           NaN  New York    Yorktown Central School District
# 1990           NaN  New York    Yorktown Central School District
# 2266           NaN  New York    Marlboro Central School District
# 2349           NaN  New York    Yorktown Central School District
#
#      date_of_challenge/removal origin_of_challenge
# 3                   2022-02-01       Administrator
# 628                 2022-01-01    Formal Challenge
# 825                 2022-01-01    Formal Challenge
# 1085                2022-01-01    Formal Challenge
# 1236                2022-04-01    Formal Challenge
# 1237                2022-03-01    Formal Challenge
# 1238                2022-01-01    Formal Challenge
# 1286                2022-01-01    Formal Challenge
# 1643                2022-01-01    Formal Challenge
# 1815                2022-01-01    Formal Challenge
# 1990                2022-01-01    Formal Challenge
# 2266                2022-02-01       Administrator
# 2349                2022-01-01    Formal Challenge

# %% [markdown]
# * there are rows with the same book because the book may be banned or attempted ban in different districts. EX: Gender Queer: A Memoir.

# %%
title_bans_by_district = banned_books_data.groupby(['state', 'district'])['title'].count().sort_values(ascending=False).reset_index()
title_bans_by_district
# Out:
#             state                                district  title
# 0    Pennsylvania            Central York School District    441
# 1           Texas  North East Independent School District    435
# 2       Tennessee                    Collierville Schools    327
# 3         Florida             Duval County Public Schools    176
# 4         Florida     Indian River County School District    161
# ..            ...                                     ...    ...
# 133  Rhode Island             Pawtucket School Department      1
# 134  Pennsylvania             Wissahickon School District      1
# 135  Pennsylvania           Kutztown Area School District      1
# 136  Pennsylvania       Franklin Regional School District      1
# 137        Alaska               Anchorage School District      1
#
# [138 rows x 3 columns]

# %%
dist_banned_books = banned_books_data[banned_books_data['district']=='Indian River County School District']['title'].value_counts().sort_values()
dist_banned_books
# Out:
# Ace of Spades                                                                                        1
# Forever...                                                                                           1
# Me and Earl and the Dying Girl                                                                       1
# How I Paid for College: A Novel of Sex, Theft, Friendship & Musical Theater (Edward Zanni Series)    1
# The Absolutely True Diary of a Part-Time Indian                                                      1
#                                                                                                     ..
# Empty                                                                                                1
# A Certain Slant of Light                                                                             1
# What Is Black Lives Matter? (What was...? Series)                                                    1
# The Music of What Happens                                                                            1
# Black Enough: Stories of Being Young & Black in America                                              1
# Name: title, Length: 161, dtype: int64

# %%
author_banned_books = banned_books_data.groupby('author')['title'].value_counts().sort_values()
author_banned_books
# Out:
# author               title
# Leavitt, Martine     My Book of Life by Angel                                            1
# Mosley, Walter       47                                                                  1
# Moskowitz, Hannah    Marco Impossible                                                    1
# Mosca, Julia Finley  The Girl with a Mind for Math: The Story of Raye Montague           1
#                      The Doctor with an Eye for Eyes: The Story of Dr. Patricia Bath     1
#                                                                                         ..
# Thomas, Angie        The Hate U Give                                                    17
# Morrison, Toni       The Bluest Eye                                                     22
# Pérez, Ashley Hope   Out of Darkness                                                    23
# Johnson, George M.   All Boys Aren't Blue                                               29
# Kobabe, Maia         Gender Queer: A Memoir                                             41
# Name: title, Length: 1656, dtype: int64

# %%
banned_books_data[banned_books_data['author']=='Kobabe, Maia']
# Out:
#             author                   title  \
# 1223  Kobabe, Maia  Gender Queer: A Memoir
# 1224  Kobabe, Maia  Gender Queer: A Memoir
# 1225  Kobabe, Maia  Gender Queer: A Memoir
# 1226  Kobabe, Maia  Gender Queer: A Memoir
# 1227  Kobabe, Maia  Gender Queer: A Memoir
# 1228  Kobabe, Maia  Gender Queer: A Memoir
# 1229  Kobabe, Maia  Gender Queer: A Memoir
# 1230  Kobabe, Maia  Gender Queer: A Memoir
# 1231  Kobabe, Maia  Gender Queer: A Memoir
# 1232  Kobabe, Maia  Gender Queer: A Memoir
# 1233  Kobabe, Maia  Gender Queer: A Memoir
# 1234  Kobabe, Maia  Gender Queer: A Memoir
# 1235  Kobabe, Maia  Gender Queer: A Memoir
# 1236  Kobabe, Maia  Gender Queer: A Memoir
# 1237  Kobabe, Maia  Gender Queer: A Memoir
# 1238  Kobabe, Maia  Gender Queer: A Memoir
# 1239  Kobabe, Maia  Gender Queer: A Memoir
# 1240  Kobabe, Maia  Gender Queer: A Memoir
# 1241  Kobabe, Maia  Gender Queer: A Memoir
# 1242  Kobabe, Maia  Gender Queer: A Memoir
# 1243  Kobabe, Maia  Gender Queer: A Memoir
# 1244  Kobabe, Maia  Gender Queer: A Memoir
# 1245  Kobabe, Maia  Gender Queer: A Memoir
# 1246  Kobabe, Maia  Gender Queer: A Memoir
# 1247  Kobabe, Maia  Gender Queer: A Memoir
# 1248  Kobabe, Maia  Gender Queer: A Memoir
# 1249  Kobabe, Maia  Gender Queer: A Memoir
# 1250  Kobabe, Maia  Gender Queer: A Memoir
# 1251  Kobabe, Maia  Gender Queer: A Memoir
# 1252  Kobabe, Maia  Gender Queer: A Memoir
# 1253  Kobabe, Maia  Gender Queer: A Memoir
# 1254  Kobabe, Maia  Gender Queer: A Memoir
# 1255  Kobabe, Maia  Gender Queer: A Memoir
# 1256  Kobabe, Maia  Gender Queer: A Memoir
# 1257  Kobabe, Maia  Gender Queer: A Memoir
# 1258  Kobabe, Maia  Gender Queer: A Memoir
# 1259  Kobabe, Maia  Gender Queer: A Memoir
# 1260  Kobabe, Maia  Gender Queer: A Memoir
# 1261  Kobabe, Maia  Gender Queer: A Memoir
# 1262  Kobabe, Maia  Gender Queer: A Memoir
# 1263  Kobabe, Maia  Gender Queer: A Memoir
#
#                              type_of_ban secondary_author(s) illustrator(s)  \
# 1223  Banned in Libraries and Classrooms                 NaN            NaN
# 1224  Banned in Libraries and Classrooms                 NaN            NaN
# 1225  Banned in Libraries and Classrooms                 NaN            NaN
# 1226        Banned Pending Investigation                 NaN            NaN
# 1227  Banned in Libraries and Classrooms                 NaN            NaN
# 1228  Banned in Libraries and Classrooms                 NaN            NaN
# 1229        Banned Pending Investigation                 NaN            NaN
# 1230  Banned in Libraries and Classrooms                 NaN            NaN
# 1231                 Banned in Libraries                 NaN            NaN
# 1232  Banned in Libraries and Classrooms                 NaN            NaN
# 1233                 Banned in Libraries                 NaN            NaN
# 1234        Banned Pending Investigation                 NaN            NaN
# 1235  Banned in Libraries and Classrooms                 NaN            NaN
# 1236        Banned Pending Investigation                 NaN            NaN
# 1237  Banned in Libraries and Classrooms                 NaN            NaN
# 1238        Banned Pending Investigation                 NaN            NaN
# 1239        Banned Pending Investigation                 NaN            NaN
# 1240        Banned Pending Investigation                 NaN            NaN
# 1241        Banned Pending Investigation                 NaN            NaN
# 1242  Banned in Libraries and Classrooms                 NaN            NaN
# 1243        Banned Pending Investigation                 NaN            NaN
# 1244                 Banned in Libraries                 NaN            NaN
# 1245        Banned Pending Investigation                 NaN            NaN
# 1246  Banned in Libraries and Classrooms                 NaN            NaN
# 1247  Banned in Libraries and Classrooms                 NaN            NaN
# 1248  Banned in Libraries and Classrooms                 NaN            NaN
# 1249  Banned in Libraries and Classrooms                 NaN            NaN
# 1250  Banned in Libraries and Classrooms                 NaN            NaN
# 1251  Banned in Libraries and Classrooms                 NaN            NaN
# 1252  Banned in Libraries and Classrooms                 NaN            NaN
# 1253  Banned in Libraries and Classrooms                 NaN            NaN
# 1254  Banned in Libraries and Classrooms                 NaN            NaN
# 1255  Banned in Libraries and Classrooms                 NaN            NaN
# 1256        Banned Pending Investigation                 NaN            NaN
# 1257        Banned Pending Investigation                 NaN            NaN
# 1258        Banned Pending Investigation                 NaN            NaN
# 1259        Banned Pending Investigation                 NaN            NaN
# 1260  Banned in Libraries and Classrooms                 NaN            NaN
# 1261        Banned Pending Investigation                 NaN            NaN
# 1262        Banned Pending Investigation                 NaN            NaN
# 1263        Banned Pending Investigation                 NaN            NaN
#
#      translator(s)           state  \
# 1223           NaN          Alaska
# 1224           NaN         Florida
# 1225           NaN         Florida
# 1226           NaN         Florida
# 1227           NaN         Florida
# 1228           NaN           Idaho
# 1229           NaN        Illinois
# 1230           NaN        Illinois
# 1231           NaN        Illinois
# 1232           NaN            Iowa
# 1233           NaN            Iowa
# 1234           NaN          Kansas
# 1235           NaN           Maine
# 1236           NaN        New York
# 1237           NaN        New York
# 1238           NaN        New York
# 1239           NaN            Ohio
# 1240           NaN    Pennsylvania
# 1241           NaN    Pennsylvania
# 1242           NaN    Pennsylvania
# 1243           NaN    Pennsylvania
# 1244           NaN    Pennsylvania
# 1245           NaN    Pennsylvania
# 1246           NaN  South Carolina
# 1247           NaN           Texas
# 1248           NaN           Texas
# 1249           NaN           Texas
# 1250           NaN           Texas
# 1251           NaN           Texas
# 1252           NaN           Texas
# 1253           NaN           Texas
# 1254           NaN           Texas
# 1255           NaN           Texas
# 1256           NaN            Utah
# 1257           NaN        Virginia
# 1258           NaN        Virginia
# 1259           NaN        Virginia
# 1260           NaN        Virginia
# 1261           NaN        Virginia
# 1262           NaN      Washington
# 1263           NaN      Washington
#
#                                            district date_of_challenge/removal  \
# 1223                      Anchorage School District                2021-10-01
# 1224                         Brevard Public Schools                2021-11-01
# 1225                   Orange County Public Schools                2021-10-01
# 1226                 Osceola County School District                2022-04-01
# 1227                        Pinellas County Schools                2021-10-01
# 1228                       West Ada School District                2022-02-01
# 1229             Community High School District 117                2021-12-01
# 1230                     Harlem School District 122                2022-03-01
# 1231                            Lake Forest Schools                2021-12-01
# 1232               Ankeny Community School District                2021-11-01
# 1233               Waukee Community School District                2021-10-01
# 1234                         Goddard Public Schools                2021-11-01
# 1235                    Regional School Unit No. 56                2022-06-01
# 1236             Connetquot Central School District                2022-04-01
# 1237             Wappingers Central School District                2022-03-01
# 1238               Yorktown Central School District                2022-01-01
# 1239                            Hudson City Schools                2021-09-01
# 1240               Downingtown Area School District                2021-10-01
# 1241          East Stroudsburg Area School District                2021-11-01
# 1242                       Fairview School District                2022-06-01
# 1243                  Kutztown Area School District                2021-11-01
# 1244                     North Penn School District                2021-09-01
# 1245                    Wissahickon School District                2021-10-01
# 1246                              Fort Mill Schools                2021-11-01
# 1247          Birdville Independent School District                2021-10-01
# 1248          Canutillo Independent School District                2021-10-01
# 1249        Clear Creek Independent School District                2021-12-01
# 1250  Cypress-Fairbanks Independent School District                2021-12-01
# 1251                                  Fort Bend ISD                2022-01-01
# 1252             Keller Independent School District                2021-11-01
# 1253            Killeen Independent School District                2021-11-01
# 1254            Prosper Independent School District                2022-01-01
# 1255      Spring Branch Independent School District                2021-11-01
# 1256                        Canyons School District                2021-10-01
# 1257                  Fairfax County Public Schools                2021-09-01
# 1258                  Hanover County Public Schools                2022-01-01
# 1259               Harrisonburg City Public Schools                2021-11-01
# 1260                  Loudoun County Public Schools                2021-09-01
# 1261             Virginia Beach City Public Schools                2021-10-01
# 1262                 Central Kitsap School District                2021-11-01
# 1263                     Walla Walla Public Schools                2022-02-01
#
#      origin_of_challenge
# 1223       Administrator
# 1224       Administrator
# 1225       Administrator
# 1226       Administrator
# 1227       Administrator
# 1228    Formal Challenge
# 1229       Administrator
# 1230    Formal Challenge
# 1231       Administrator
# 1232    Formal Challenge
# 1233       Administrator
# 1234       Administrator
# 1235    Formal Challenge
# 1236    Formal Challenge
# 1237    Formal Challenge
# 1238    Formal Challenge
# 1239       Administrator
# 1240       Administrator
# 1241       Administrator
# 1242       Administrator
# 1243       Administrator
# 1244       Administrator
# 1245       Administrator
# 1246       Administrator
# 1247    Formal Challenge
# 1248       Administrator
# 1249       Administrator
# 1250       Administrator
# 1251    Formal Challenge
# 1252    Formal Challenge
# 1253       Administrator
# 1254       Administrator
# 1255       Administrator
# 1256       Administrator
# 1257    Formal Challenge
# 1258       Administrator
# 1259       Administrator
# 1260       Administrator
# 1261       Administrator
# 1262       Administrator
# 1263    Formal Challenge

# %%
author_title_bans_by_district = banned_books_data.groupby(['author','state'])['district'].count().sort_values(ascending=False).reset_index()
author_title_bans_by_district
# Out:
#                       author         state  district
# 0                    Do, Anh  Pennsylvania        17
# 1             Faruqi, Saadia  Pennsylvania        16
# 2          Jules, Jacqueline  Pennsylvania        16
# 3             Hopkins, Ellen       Florida        15
# 4             Hopkins, Ellen         Texas        14
# ...                      ...           ...       ...
# 1658           Hoffman, Eric         Texas         1
# 1659            Hoblin, Paul         Texas         1
# 1660             Ho, Minfong       Florida         1
# 1661      Hitchcock, Shannon         Texas         1
# 1662  Àbíké-Íyímídé, Faridah       Florida         1
#
# [1663 rows x 3 columns]

# %%
import pycountry

# %%
def findCountry (country_name):
    try:
        return pycountry.countries.get(name=country_name).alpha_2
    except:
        return ("not founded")
    
banned_books_data['state_alpha'] = banned_books_data.apply(lambda row: findCountry(row.state) , axis = 1)

# %%
banned_books_data['state_alpha']
# Out:
# 0       not founded
# 1       not founded
# 2       not founded
# 3       not founded
# 4       not founded
#            ...
# 2527    not founded
# 2528    not founded
# 2529    not founded
# 2530    not founded
# 2531    not founded
# Name: state_alpha, Length: 2532, dtype: object
